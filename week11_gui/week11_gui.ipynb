# %% [markdown]
# # Lab: Recursion and GUI Programming
#
# **Course:** IST1012 - Python Programming II
# **Duration:** ~40 minutes
# **Lab Type:** Hands-on Guided Exercises
#
# ---
#
# ## Description
#
# In this lab, you will explore two powerful concepts: **recursion** (functions that call themselves) and **GUI programming** using Python's built-in `tkinter` library. You will write small recursive functions and then connect them to a simple graphical interface to build a mini security-themed tool.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lab, you will be able to:
#
# 1. Identify the **base case** and **recursive case** in a recursive function.
# 2. Write simple recursive functions for counting and string problems.
# 3. Build a basic GUI window using `tkinter` with labels, entry fields, and buttons.
# 4. Connect Python logic to a button click event.
# 5. Combine recursion + GUI to build a small security-flavored interactive tool.

# %% [markdown]
# ---
# ## Section 1: Warm-up (5 minutes)
#
# Answer the conceptual questions below, then run the short Python snippet.

# %% [markdown]
# ### Quick Python Recall
#
# **Predict** the output before running this cell.

# %%
# Predict the output, then run.
def greet(name):
    return "Hello, " + name

print(greet("Analyst"))
print(greet("Admin"))
# Out:
# Hello, Analyst
# Hello, Admin

# %% [markdown]
# ---
# ## Section 2: Core Concepts (10 minutes)
#
# ### 2.1 What is Recursion?
#
# A **recursive function** is a function that calls itself to solve a smaller version of the same problem.
#
# Every recursive function has two parts:
#
# - **Base case** — the simplest input, where the function stops calling itself.
# - **Recursive case** — the function calls itself with a smaller input.
#
# Think of it like opening nested folders: you keep opening one inside another until you reach an empty folder (the base case).
#
# #### Tiny Example: Countdown

# %%
# Recursive countdown
def countdown(n):
    if n <= 0:                # base case
        print("Done!")
    else:
        print(n)
        countdown(n - 1)      # recursive case

countdown(3)
# Out:
# 3
# 2
# 1
# Done!

# %% [markdown]
# ### 2.2 What is a GUI?
#
# A **GUI** (Graphical User Interface) lets users interact through windows, buttons, and text boxes instead of typing commands.
#
# Python's built-in `tkinter` library lets us create GUIs quickly. The main building blocks are:
#
# - `Tk()` — creates the main window
# - `Label` — shows text
# - `Entry` — input box for the user
# - `Button` — runs a function when clicked
#
# #### Tiny Example: A Hello Window
#
# > **Note:** When you run a `tkinter` cell, a new window will open. **Close that window** before running the next cell.

# %%
import tkinter as tk

window = tk.Tk()
window.title("My First GUI")
window.geometry("300x100")

label = tk.Label(window, text="Hello, Cybersecurity Student!")
label.pack(pady=20)

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_691/2107695117.py in <cell line: 0>()
#       1 import tkinter as tk
#       2
# ----> 3 window = tk.Tk()
#       4 window.title("My First GUI")
#       5 window.geometry("300x100")
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# ### 2.3 Connecting a Button to a Function
#
# A button can run a Python function when clicked. We pass the function name to `command=`.
#
# > Remember to close the previous window before running this.

# %%
import tkinter as tk

def show_message():
    label.config(text="Button was clicked!")

window = tk.Tk()
window.title("Button Demo")
window.geometry("300x120")

label = tk.Label(window, text="Click the button below")
label.pack(pady=10)

button = tk.Button(window, text="Click Me", command=show_message)
button.pack()

window.mainloop()

# %% [markdown]
# ---
# ## Section 3: Guided Exercises (20 minutes)
#
# Complete each task in the code cell provided. **Do not skip steps.** Each task builds on the previous one.

# %% [markdown]
# ### Task 1 — Recursive Sum
#
# Write a recursive function `sum_to(n)` that returns the sum of all integers from `1` to `n`.
#
# - Example: `sum_to(4)` should return `10` (because 1 + 2 + 3 + 4 = 10).
# - Identify your base case first.
# - Do **not** use a loop or the built-in `sum()` function.
#
# Test your function with `sum_to(4)` and `sum_to(10)`.

# %%
# Task 1: Write your recursive sum_to(n) function here

def sum_to(n):
    if n > 0:
        return n + sum_to(n - 1)
    else:
        return 0

# Test your function
print(sum_to(4))
print(sum_to(10))
# Out:
# 10
# 55

# %% [markdown]
# ### Task 2 — Count Characters in a Password
#
# Write a recursive function `count_chars(text)` that returns the number of characters in a string **without** using `len()`.
#
# - Example: `count_chars("admin")` should return `5`.
# - Hint: think about what the "smaller problem" looks like when you remove one character.
#
# This kind of length check is used in password policy validation.

# %%
# Task 2: Write your recursive count_chars function here

def count_chars(text):
    if text == "":
        return 0
    else:
        return 1 + count_chars(text[1:])

# Test your function
print(count_chars("admin"))
print(count_chars("P@ssw0rd!"))
# Out:
# 5
# 9

# %% [markdown]
# ### Task 3 — Reverse a String Recursively
#
# Write a recursive function `reverse_str(text)` that returns the reversed version of a string.
#
# - Example: `reverse_str("login")` should return `"nigol"`.
# - Do **not** use slicing tricks like `text[::-1]`.
#
# Reversing strings is a common step in simple obfuscation and CTF challenges.

# %%
# Task 3: Write your recursive reverse_str function here

def reverse_str(text):
    if len(text) == 0:
        return ""
    else:
        return reverse_str(text[1:]) + text[0]


# Test your function
print(reverse_str("login"))
print(reverse_str("cybersecurity"))
# Out:
# nigol
# ytirucesrebyc

# %% [markdown]
# ### Task 4 — Simple Login Window
#
# Build a `tkinter` window that asks the user to enter a username.
#
# Requirements:
# - Window title: `"Login Check"`
# - A `Label` that says `"Enter username:"`
# - An `Entry` field for the username
# - A `Button` labeled `"Submit"` that, when clicked, updates a second label to say `"Welcome, <username>"`
#
# Use string concatenation (no f-strings — Python 3.5 compatible).
#
# > Close the window when you're done testing.

# %%
import tkinter as tk

def login():
    username = username_entry.get()
    welcome_label.config(text=f"Welcome, {username}")
    username_entry.delete(0, tk.END)

window = tk.Tk()
window.title("Login Check")

username_label = tk.Label(window, text="Enter username:")
username_label.pack(pady=10)

username_entry = tk.Entry(window)
username_entry.pack()

login_button = tk.Button(window, text="Submit", command=login)
login_button.pack(pady=10)

welcome_label = tk.Label(window, text="")
welcome_label.pack()

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_691/364342444.py in <cell line: 0>()
#       6     username_entry.delete(0, tk.END)
#       7
# ----> 8 window = tk.Tk()
#       9 window.title("Login Check")
#      10
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# ---
# ## Section 4: Challenge Section (5 minutes)
#
# ### Challenge — Recursive Password Strength Checker (GUI)
#
# Build a small GUI tool that checks password length using **your recursive `count_chars` function** from Task 2.
#
# Requirements:
# - Window title: `"Password Length Checker"`
# - An `Entry` field where the user types a password
# - A `Button` labeled `"Check"`
# - When the button is clicked:
#   - If the password length (computed by `count_chars`) is **less than 8**, show: `"Weak password"`
#   - Otherwise, show: `"Acceptable length"`
#
# Do **not** use `len()` anywhere — your recursive function must do the counting.

# %%
import tkinter as tk

def count_chars(text):
    if text == "":
        return 0
    else:
        return 1 + count_chars(text[1:])

def check_password():
    password = password_entry.get()
    length = count_chars(password)

    if length < 8:
        result_label.config(text="Weak password")
    else:
        result_label.config(text="Acceptable password")

    password_entry.delete(0, tk.END)

window = tk.Tk()
window.title("Password Length Checker")

password_label = tk.Label(window, text="Enter password:")
password_label.pack(pady=10)

password_entry = tk.Entry(window)
password_entry.pack()

check_button = tk.Button(window, text="Check", command=check_password)
check_button.pack(pady=10)

result_label = tk.Label(window, text="")
result_label.pack()

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_691/2786551239.py in <cell line: 0>()
#      18
#      19 window = tk.Tk
# ---> 20 window.title("Password Length Checker")
#      21
#      22 password_label = tk.Label(window, text="Enter password:")
#
# /usr/lib/python3.12/tkinter/__init__.py in wm_title(self, string)
#    2303     def wm_title(self, string=None):
#    2304         """Set the title of this widget."""
# -> 2305         return self.tk.call('wm', 'title', self._w, string)
#    2306
#    2307     title = wm_title
#
# AttributeError: 'str' object has no attribute 'tk'

# %% [markdown]
# ---
# ## Wrap-up
#
# Before submitting, make sure:
#
# - All code cells run without errors.
# - You answered the warm-up questions.
# - Your GUI windows open and respond to button clicks.
# - Your recursive functions use a clear base case (no infinite recursion!).
#
# Save your notebook and submit it according to your instructor's guidelines.
